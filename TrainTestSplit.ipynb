# %% [markdown]
# # Polynomial Regression
# We are going to use Train_test split to prevent overfitting in our Polynomial Regression problem

# %%
# %matplotlib inline
import numpy as np
from pylab import *

np.random.seed(2)

pageSpeeds = np.random.normal(3.0, 1.0, 100)
purchaseAmount = np.random.normal(50.0, 30.0, 100) / pageSpeeds


scatter(pageSpeeds, purchaseAmount)

# %% [markdown]
# Now we split the data into 80% train and 20% test

# %%
trainX = pageSpeeds[:80]
testX = pageSpeeds[80:]

trainY = purchaseAmount[:80]
testY = purchaseAmount[80:]

# %%
#Our training data
scatter(trainX, trainY)

# %%
#Our Test data
scatter(testX, testY)

# %% [markdown]
# Now we'll try to fit an 8th-degree polynomial to this data (which is almost certainly overfitting, given what we know about how it was generated!)

# %%
x = np.array(trainX)
y = np.array(trainY)

p4 = np.poly1d(np.polyfit(x, y, 8))

# %% [markdown]
# Let's plot our polynomial line against our training data

# %%
import matplotlib.pyplot as plt

xp = np.linspace(0, 7, 100)
axes = plt.axes()
axes.set_xlim([0,7])
axes.set_ylim([0, 200])
plt.scatter(x, y)
plt.plot(xp, p4(xp), c='r')
plt.show()

# %% [markdown]
# Against our test data

# %%
testx = np.array(testX)
testy = np.array(testY)

axes = plt.axes()
axes.set_xlim([0,7])
axes.set_ylim([0, 200])
plt.scatter(testx, testy)
plt.plot(xp, p4(xp), c='r')
plt.show()

# %% [markdown]
# Doesn't look bad but let's verify with r_squared error

# %%
from sklearn.metrics import r2_score

r2 = r2_score(testy, p4(testx))

print(r2)
# Out:
# 0.3001816861115417

# %% [markdown]
# This shows it is horrible even though it fits the training data

# %%
from sklearn.metrics import r2_score

r2 = r2_score(np.array(trainY), p4(np.array(trainX)))

print(r2)
# Out:
# 0.6427069514689596
